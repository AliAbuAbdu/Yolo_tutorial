# %%
# !pip install opencv-python
# Out:
# ...
#   Using cached numpy-2.4.6-cp312-cp312-win_amd64.whl.metadata (6.6 kB)
# Using cached numpy-2.4.6-cp312-cp312-win_amd64.whl (12.3 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ...

# %%
import numpy as np

# %%
import cv2

# %%
img = cv2.imread("C:\\Users\\mrgum\\Desktop\\Yolo_tutorial\\cat.jpg", cv2.IMREAD_COLOR)

# %%
img = img * 2

# %%
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#print(rgb_img[0, 0])
#print(img[0, 0])
#cv2.imshow("Cat", img)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2.imwrite("C:\\Users\\mrgum\\Desktop\\Yolo_tutorial\\gray_cat.jpg", gray_img)
# Out:
# True

# %%
img = cv2.imread("C:\\Users\\mrgum\\Desktop\\Yolo_tutorial\\cat.jpg", cv2.IMREAD_GRAYSCALE)
